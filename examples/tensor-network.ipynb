# %% [markdown]
# # Tensor Network

# %%
using Tangles

# %% [markdown]
# The most fundamental interface in Tangles is `TensorNetwork`. It defines the methods that need to be implemented by a "Tensor Network": access to tensors, inds and adding/removing/replacing them too. It is defined in [src/Interfaces/TensorNetwork.jl](../src/Interfaces/TensorNetwork.jl).
#
# `SimpleTensorNetwork` is a concrete type that implements both the `TensorNetwork` and `Network` interfaces.
#
# > [!NOTE]
# > `SimpleTensorNetwork` is basically a copy-paste of old Tenet's `TensorNetwork` refactored to fit the new interfaces.

# %%
A = Tensor(rand(2,2), [Index(:i), Index(:j)])
B = Tensor(rand(2,2), [Index(:j), Index(:k)])
tn = SimpleTensorNetwork([A, B])
# Out:
# SimpleTensorNetwork (#tensors=2, #inds=3)

# %% [markdown]
# ## Tensors

# %% [markdown]
# To access the tensors in a Tensor Network, there is the explicit `tensors_*` methods or the keyword-dispatched `tensors` function.
#
# If you want to get all the tensors, you can call `all_tensors` or just `tensors`.

# %%
tensors(tn)
# Out:
# 2-element Vector{Tensor}:
#  [0.3439548105429502 0.12745622217190233; 0.3391572303461966 0.7136988455208723]
#  [0.21789924693333884 0.49456248077040244; 0.504965638067504 0.9068473840703845]

# %% [markdown]
# `tensors_set_equal` (aka `tensors(; withinds)`) returns the `Tensor`s whose `inds` match the ones passed down.

# %%
tensors(tn; withinds=[Index(:i), Index(:j)])
# Out:
# 1-element Vector{Tensor{Float64, 2, Matrix{Float64}}}:
#  [0.3439548105429502 0.12745622217190233; 0.3391572303461966 0.7136988455208723]

# %% [markdown]
# `tensors_set_contain` (aka `tensors(; contain)`) returns all the `Tensor`s whose `inds` contain **all** the indices you pass.

# %%
tensors(tn; contain=Index(:i))
# Out:
# 1-element Vector{Tensor{Float64, 2, Matrix{Float64}}}:
#  [0.3439548105429502 0.12745622217190233; 0.3391572303461966 0.7136988455208723]

# %% [markdown]
# `tensors_set_intersect` (aka `tensors(; intersect)`) returns all the `Tensors` whose `inds` **intersect** with the ones you pass (i.e. contain at least one).

# %%
tensors(tn; intersect=Index(:i))
# Out:
# 1-element Vector{Tensor}:
#  [0.3439548105429502 0.12745622217190233; 0.3391572303461966 0.7136988455208723]

# %% [markdown]
# The difference between `intersect` and `contain` arises when you pass a list of indices.

# %%
tensors(tn; contain=[Index(:i), Index(:k)])
# Out:
# Tensor{Float64, 2, Matrix{Float64}}[]

# %%
tensors(tn; intersect=[Index(:i), Index(:k)])
# Out:
# 2-element Vector{Tensor}:
#  [0.3439548105429502 0.12745622217190233; 0.3391572303461966 0.7136988455208723]
#  [0.21789924693333884 0.49456248077040244; 0.504965638067504 0.9068473840703845]

# %% [markdown]
# `ntensors` returns the number of tensors in a Tensor Network, and accepts the same keyword arguments as `tensors`. The reason for it to be used instead of `length(tensors(...))` is that it can be wayyy faster on some ocassions, so it's better to use `ntensors` if you're gonna call it a lot of times.

# %%
ntensors(tn)
# Out:
# 2

# %%
ntensors(tn; contain=Index(:j))
# Out:
# 2

# %% [markdown]
# `hastensor` checks if a certain `Tensor` is inside the Tensor Network. Note that in Tangles (and Tenet), we use "egality" (i.e. `===`) to check for belonging. So even if 2 `Tensor`s are equal, it won't matter: it needs to be the **exact same tensor**.

# %%
hastensor(tn, A)
# Out:
# true

# %%
hastensor(tn, Tensor(rand(2,2), [Index(:i), Index(:j)]))
# Out:
# false

# %% [markdown]
# ## Indices

# %% [markdown]
# `all_inds` (aka `inds`) returns all the indices present in the Tensor Network.

# %%
inds(tn)
# Out:
# 3-element Vector{Index}:
#  Index{Symbol}(:i)
#  Index{Symbol}(:j)
#  Index{Symbol}(:k)

# %% [markdown]
# `inds_set_open` (aka `inds(; set=:open)`) returns the open indices (i.e. indices appearing in only 1 tensor).

# %%
inds(tn; set=:open)
# Out:
# 2-element Vector{Index}:
#  Index{Symbol}(:i)
#  Index{Symbol}(:k)

# %% [markdown]
# `inds_set_inner` (aka `inds(; set=:inner)`) returns the inner indices (i.e. indices appearing in just 2 tensors).

# %%
inds(tn; set=:inner)
# Out:
# 1-element Vector{Index}:
#  Index{Symbol}(:j)

# %% [markdown]
# `inds_set_hyper` (aka `inds(; set=:hyper)`) returns the hyper indices (i.e. indices appearing in 3 or more tensors).

# %%
inds(tn; set=:hyper)
# Out:
# Index[]

# %% [markdown]
# `inds_parallel_to` (aka `inds(; parallel_to)`) returns any other index "parallel" to the one passed.

# %%
inds(tn; parallel_to=Index(:i))
# Out:
# Index[]

# %% [markdown]
# Just like with `ntensors` and `hastensor`, there exist its `inds` counterparts: `ninds` and `hasind`.

# %%
ninds(tn)
# Out:
# 3

# %%
ninds(tn; set=:open)
# Out:
# 2

# %%
hasind(tn, Index(:i))
# Out:
# true

# %%
hasind(tn, Index(:not_i))
# Out:
# false

# %% [markdown]
# Calling `size_inds` (aka `Base.size`) on a Tensor Network, returns a `Dict` that maps `Index` to their sizes.

# %%
size(tn)
# Out:
# Dict{Index, Int64} with 3 entries:
#   Index{Symbol}(:i) => 2
#   Index{Symbol}(:j) => 2
#   Index{Symbol}(:k) => 2

# %% [markdown]
# `size_ind` (aka `Base.size` with an `Index` as the 2nd argument) returns the size for just the passed `Index`.

# %%
size(tn, Index(:i))
# Out:
# 2

# %% [markdown]
# ## Mutation

# %% [markdown]
# ### Adding a tensor

# %%
tensor = Tensor(rand(2,2), [Index(:i), Index(:i2)])
addtensor!(tn, tensor)
# Out:
# SimpleTensorNetwork (#tensors=3, #inds=4)

# %% [markdown]
# ### Renaming an index

# %%
replace_ind!(tn, Index(:i), Index(plug"1"))
# Out:
# SimpleTensorNetwork (#tensors=3, #inds=4)

# %%
replace!(tn, Index(:k) => Index(plug"2"))
replace!(tn, Index(:j) => Index(bond"1-2"))
# Out:
# SimpleTensorNetwork (#tensors=3, #inds=4)

# %%
inds(tn)
# Out:
# 4-element Vector{Index}:
#  Index{Symbol}(:i2)
#  Index{Plug{CartesianSite{1}}}((1,))
#  Index{Bond{CartesianSite{1}, CartesianSite{1}}}((1,) <=> (2,))
#  Index{Plug{CartesianSite{1}}}((2,))

# %% [markdown]
# ### Removing a tensor

# %%
rmtensor!(tn, tensor)
# Out:
# ArgumentError: Tensor not found
#
#
#
# Stacktrace:
#
#  [1] rmtensor!(tn::SimpleTensorNetwork, tensor::Tensor{Float64, 2, Matrix{Float64}})
#
#    @ Tangles ~/Developer/Tangles.jl/src/Components/SimpleTensorNetwork.jl:207
#
#  [2] top-level scope
#
#    @ ~/Developer/Tangles.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y101sZmlsZQ==.jl:1

# %% [markdown]
# Index `:i` has been renamed and `Tensor`  is "immutable" (the `Tensor` object itself and the indices are immutable, but the array can be mutated if it allows so) so `tensor` has been replaced by another `Tensor`.

# %%
tensor = only(tensors(tn; contain=Index(:i2)))
# Out:
# 2×2 Tensor{Float64, 2, Matrix{Float64}}:
#  0.991685  0.471111
#  0.912472  0.465757

# %%
rmtensor!(tn, tensor)
# Out:
# SimpleTensorNetwork (#tensors=2, #inds=4)

# %% [markdown]
# ## Delegation
#
# If you want to build another Tensor Network type on top of a type that implements the `TensorNetwork` interface (e.g. `GenericTensorNetwork`), Tangles uses a "delegation" mechanism that automatically implements and calls the correct methods for you.
#
# The only thing you need to do is to define `DelegatorTrait` for your type.
#
# For more information, check out [DelegatorTraits.jl](https://github.com/bsc-quantic/DelegatorTraits.jl).

# %%
struct MyTensorNetwork <: Tangles.AbstractTensorNetwork
    tn::SimpleTensorNetwork
end

MyTensorNetwork() = MyTensorNetwork(SimpleTensorNetwork())
Tangles.DelegatorTrait(::Tangles.TensorNetwork, tn::MyTensorNetwork) = Tangles.DelegateTo{:tn}()

# %%
my_tn = MyTensorNetwork()
# Out:
# UndefVarError: `DelegateTo` not defined in `Tangles`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#   [1] DelegatorTraits.DelegatorTrait(::TensorNetwork, tn::MyTensorNetwork)
#
#     @ Main ~/Developer/Tangles.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y106sZmlsZQ==.jl:6
#
#   [2] ntensors(::@NamedTuple{}, tn::MyTensorNetwork)
#
#     @ Tangles ~/Developer/Tangles.jl/src/Interfaces/TensorNetwork.jl:164
#
#   [3] ntensors
#
#     @ ~/Developer/Tangles.jl/src/Interfaces/TensorNetwork.jl:156 [inlined]
#
#   [4] show
#
#     @ ~/Developer/Tangles.jl/src/Operations/AbstractTensorNetwork.jl:9 [inlined]
#
#   [5] show
#
#     @ ./multimedia.jl:47 [inlined]
#
#   [6] limitstringmime(mime::MIME{Symbol("text/plain")}, x::MyTensorNetwork)
#
#     @ VSCodeServer.IJuliaCore ~/.vscode/extensions/julialang.language-julia-1.146.2/scripts/packages/IJuliaCore/src/inline.jl:22
#
#   [7] display_mimestring(m::MIME{Symbol("text/plain")}, x::MyTensorNetwork)
#
#     @ VSCodeServer.IJuliaCore ~/.vscode/extensions/julialang.language-julia-1.146.2/scripts/packages/IJuliaCore/src/display.jl:67
#
#   [8] display_dict(x::MyTensorNetwork)
#
#     @ VSCodeServer.IJuliaCore ~/.vscode/extensions/julialang.language-julia-1.146.2/scripts/packages/IJuliaCore/src/display.jl:98
#
#   [9] display(::VSCodeServer.JuliaNotebookInlineDisplay, x::MyTensorNetwork)
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.146.2/scripts/packages/VSCodeServer/src/notebookdisplay.jl:32
#
#  [10] display(x::Any)
#
#     @ Base.Multimedia ./multimedia.jl:340
#
#  [11] #invokelatest#2
#
#     @ ./essentials.jl:1055 [inlined]
#
#  [12] invokelatest
#
#     @ ./essentials.jl:1052 [inlined]
#
#  [13] (::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String})()
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.146.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:54
#
#  [14] withpath(f::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.146.2/scripts/packages/VSCodeServer/src/repl.jl:276
#
#  [15] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.146.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:13
#
#  [16] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
#
#     @ VSCodeServer.JSONRPC ~/.vscode/extensions/julialang.language-julia-1.146.2/scripts/packages/JSONRPC/src/typed.jl:68
#
#  [17] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#7#12"{String})
#
#     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.146.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:147
#
#  [18] top-level scope
#
#     @ ~/.vscode/extensions/julialang.language-julia-1.146.2/scripts/notebook/notebook.jl:35

# %%
tensor = Tensor(rand(2,2), [Index(:i), Index(:j)])
addtensor!(my_tn, tensor)
tensors(my_tn)
# Out:
# UndefVarError: `DelegateTo` not defined in `Tangles`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] DelegatorTraits.DelegatorTrait(::TensorNetwork, tn::MyTensorNetwork)
#
#    @ Main ~/Developer/Tangles.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y106sZmlsZQ==.jl:6
#
#  [2] addtensor!(tn::MyTensorNetwork, tensor::Tensor{Float64, 2, Matrix{Float64}})
#
#    @ Tangles ~/Developer/Tangles.jl/src/Interfaces/TensorNetwork.jl:288
#
#  [3] top-level scope
#
#    @ ~/Developer/Tangles.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y111sZmlsZQ==.jl:2

# %%
replace_ind!(my_tn, Index(:i), Index(:new_i))
# Out:
# UndefVarError: `DelegateTo` not defined in `Tangles`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] DelegatorTraits.DelegatorTrait(::TensorNetwork, tn::MyTensorNetwork)
#
#    @ Main ~/Developer/Tangles.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y106sZmlsZQ==.jl:6
#
#  [2] replace_ind!(tn::MyTensorNetwork, old::Index{Symbol}, new::Index{Symbol})
#
#    @ Tangles ~/Developer/Tangles.jl/src/Interfaces/TensorNetwork.jl:312
#
#  [3] top-level scope
#
#    @ ~/Developer/Tangles.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y112sZmlsZQ==.jl:1

# %%
inds(my_tn)
# Out:
# UndefVarError: `DelegateTo` not defined in `Tangles`
#
# Suggestion: check for spelling errors or missing imports.
#
#
#
# Stacktrace:
#
#  [1] DelegatorTraits.DelegatorTrait(::TensorNetwork, tn::MyTensorNetwork)
#
#    @ Main ~/Developer/Tangles.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y106sZmlsZQ==.jl:6
#
#  [2] all_inds(tn::MyTensorNetwork)
#
#    @ Tangles ~/Developer/Tangles.jl/src/Interfaces/TensorNetwork.jl:110
#
#  [3] inds
#
#    @ ~/Developer/Tangles.jl/src/Operations/AbstractTensorNetwork.jl:13 [inlined]
#
#  [4] inds(tn::MyTensorNetwork)
#
#    @ Tangles ~/Developer/Tangles.jl/src/Operations/AbstractTensorNetwork.jl:12
#
#  [5] top-level scope
#
#    @ ~/Developer/Tangles.jl/examples/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_Y113sZmlsZQ==.jl:1
